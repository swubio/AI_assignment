# %% [markdown]
# 코로나 검사에서 양성 판정이 나왔다. 실제로 코로나에 감염되었을 확률은?
# 실제로 코로나에 걸릴 확률은 0.01 (1%)로 가정하자.

# %% [markdown]
# :
# 양성일 때, 코로나일 확률 = ?
# 코로나일 때, 양성일 확률 = 0.96
# 코로나일 확률 = 0.01
# 양성일 확률 = (코로나에 양성)*코로나일 확률 + (코로나 X일 때 양성)*코로나 X일 확률
#            = 0.0096 + 0.01386 = 0.02346
# (코로나일 때, 양성일 확률)*코로나일 확률/양성일 확률 = 양성일 때, 코로나일 확률 = 0.409...
